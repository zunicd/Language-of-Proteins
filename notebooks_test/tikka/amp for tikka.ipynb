# %% [markdown]
# You need fasta file and tar.gz file. See below.

# %%
# !tree ../data/amp -hDL 3
# Out:
# ../data/amp
# ├── [193K Feb  3  2022]  all_data.csv
# ├── [216K Sep  3 22:34]  all_data.fa
# ├── [4.0K Sep  3 10:09]  esm
# │   └── [4.0K Sep  3 10:09]  all_data
# └── [4.0K Sep  3 10:10]  prose
#     └── [4.0K Sep  4 18:03]  all_data
#         ├── [4.0K Sep  4 17:39]  amp_all_dlm_avg
#         ├── [ 97M Sep  4 17:21]  amp_all_dlm_avg.h5
#         └── [ 89M Sep  4 18:03]  amp_all_dlm_avg.tar.gz
#
# 5 directories, 4 files

# %% [markdown]
# For now we will use the tool from esm to read fasta file.
# Later I might find another way.
# To use it, you have to install esm:
# `pip install fair-esm`
#
# Then, import esm as I did below.
#
# you will need to extract the tar.gz file.
#
# Use this [link](https://logfetch.com/wsl2-zip-unzip-files/) to unzip and untar the file.
#
# You may try with windows tool also. Ping me if you will need any help.
#
# Code below I adjusted form this notebook  https://github.com/facebookresearch/esm/blob/main/examples/sup_variant_prediction.ipynb
#
# It will create X as an array and y as a list.
#
# From them you should be able to create a dataframe.

# %%
import esm
import torch
import numpy as np

# %%
path_fa = '../data/amp/all_data.fa'
# path_h5 = '../data/amp/prose/all_data/amp_all_dlm_avg.h5'
path_pt = '../data/amp/prose/all_data/amp_all_dlm_avg'
emb_layer = 'layer'
pool = 'avg'

# %%
ys = []
Xs = []
seq_id = []

for header, _seq in esm.data.read_fasta(path_fa):
    label = header.split('|')[-1]
    ys.append(float(label))   # see if you need integer or afloat
    seq = header.split('|')[-2]
    seq_id.append(seq)
    fn = f'{path_pt}/{header[1:]}.pt'
    embs = torch.load(fn)
    Xs.append(embs[f'{pool}_representations'][emb_layer])
Xs = torch.stack(Xs, dim=0).numpy()
print(len(ys))
print(Xs.shape)
print(len(seq_id))
# Out:
# 4042
# (4042, 6165)
# 4042

# %%
print(type(ys))
print(type(Xs))
print(type(seq_id))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'list'>

# %%
Xs
# Out:
# array([[ 0.1904762 ,  0.        ,  0.        , ..., -0.07591449,
#         -0.01412157,  0.01358508],
#        [ 0.        ,  0.02325581,  0.04651163, ...,  0.05043951,
#         -0.0538577 , -0.12193269],
#        [ 0.20000002,  0.        ,  0.        , ..., -0.08004365,
#          0.07211193, -0.03114778],
#        ...,
#        [ 0.11320755,  0.01886792,  0.05660377, ..., -0.04887858,
#         -0.03788646,  0.02409669],
#        [ 0.        ,  0.        ,  0.        , ...,  0.01287932,
#          0.0615775 ,  0.17003648],
#        [ 0.        ,  0.        ,  0.04      , ..., -0.09218226,
#          0.05127459,  0.05520697]], dtype=float32)

# %%
import pandas as pd
df = pd.DataFrame(Xs, index=seq_id ).reset_index().rename(columns={'index':'sequence'})
df
# Out:
#              sequence         0         1         2         3         4  \
# 0             AP02484  0.190476  0.000000  0.000000  0.000000  0.000000
# 1             AP02630  0.000000  0.023256  0.046512  0.023256  0.162791
# 2             AP01427  0.200000  0.000000  0.000000  0.033333  0.066667
# 3             AP02983  0.095238  0.190476  0.000000  0.000000  0.000000
# 4             AP01815  0.041667  0.145833  0.000000  0.041667  0.125000
# ...               ...       ...       ...       ...       ...       ...
# 4037  UniRef50_C5DJ44  0.116279  0.023256  0.058140  0.011628  0.011628
# 4038  UniRef50_Q9XUP3  0.081395  0.023256  0.034884  0.023256  0.023256
# 4039  UniRef50_Q9Y573  0.113208  0.018868  0.056604  0.037736  0.037736
# 4040  UniRef50_Q54H44  0.000000  0.000000  0.000000  0.066667  0.000000
# 4041  UniRef50_Q50L39  0.000000  0.000000  0.040000  0.040000  0.000000
#
#              5         6         7         8  ...      6155      6156  \
# 0     0.000000  0.000000  0.190476  0.000000  ... -0.074216  0.125029
# 1     0.046512  0.000000  0.093023  0.046512  ... -0.011951 -0.139132
# 2     0.033333  0.066667  0.066667  0.000000  ... -0.034706  0.061255
# 3     0.047619  0.047619  0.142857  0.047619  ... -0.061731  0.040203
# 4     0.020833  0.000000  0.125000  0.000000  ... -0.013842 -0.147841
# ...        ...       ...       ...       ...  ...       ...       ...
# 4037  0.093023  0.127907  0.046512  0.023256  ...  0.004283 -0.087141
# 4038  0.023256  0.069767  0.069767  0.011628  ... -0.015495 -0.062792
# 4039  0.018868  0.113208  0.056604  0.018868  ... -0.006378 -0.136874
# 4040  0.066667  0.066667  0.000000  0.133333  ... -0.002670 -0.064352
# 4041  0.080000  0.080000  0.000000  0.080000  ...  0.017772  0.165536
#
#           6157      6158      6159      6160      6161      6162      6163  \
# 0     0.000287  0.031710  0.045591 -0.068033  0.031241 -0.075914 -0.014122
# 1    -0.051193  0.108947 -0.014495 -0.107359  0.016725  0.050440 -0.053858
# 2    -0.004903  0.041961  0.052808 -0.083791  0.009830 -0.080044  0.072112
# 3    -0.007535  0.038144  0.009323 -0.134387  0.005756 -0.134904 -0.035848
# 4    -0.013836  0.051293  0.002145 -0.141400  0.038845 -0.136291  0.054276
# ...        ...       ...       ...       ...       ...       ...       ...
# 4037 -0.016207  0.027803 -0.015408 -0.128817 -0.115971 -0.076693  0.077499
# 4038  0.001243  0.043942  0.015509 -0.140289  0.023302 -0.101669  0.015073
# 4039 -0.010065  0.022892  0.006662 -0.144792  0.014618 -0.048879 -0.037886
# 4040 -0.036118  0.038847 -0.005325 -0.162470 -0.013375  0.012879  0.061577
# 4041 -0.026004  0.047379 -0.002521 -0.150257  0.028818 -0.092182  0.051275
#
#           6164
# 0     0.013585
# 1    -0.121933
# 2    -0.031148
# 3     0.051515
# 4    -0.005753
# ...        ...
# 4037  0.173814
# 4038  0.017768
# 4039  0.024097
# 4040  0.170036
# 4041  0.055207
#
# [4042 rows x 6166 columns]

# %%
df = pd.concat([df, pd.DataFrame(ys, columns =['label'])], axis=1)
df
# Out:
#              sequence         0         1         2         3         4  \
# 0             AP02484  0.190476  0.000000  0.000000  0.000000  0.000000
# 1             AP02630  0.000000  0.023256  0.046512  0.023256  0.162791
# 2             AP01427  0.200000  0.000000  0.000000  0.033333  0.066667
# 3             AP02983  0.095238  0.190476  0.000000  0.000000  0.000000
# 4             AP01815  0.041667  0.145833  0.000000  0.041667  0.125000
# ...               ...       ...       ...       ...       ...       ...
# 4037  UniRef50_C5DJ44  0.116279  0.023256  0.058140  0.011628  0.011628
# 4038  UniRef50_Q9XUP3  0.081395  0.023256  0.034884  0.023256  0.023256
# 4039  UniRef50_Q9Y573  0.113208  0.018868  0.056604  0.037736  0.037736
# 4040  UniRef50_Q54H44  0.000000  0.000000  0.000000  0.066667  0.000000
# 4041  UniRef50_Q50L39  0.000000  0.000000  0.040000  0.040000  0.000000
#
#              5         6         7         8  ...      6156      6157  \
# 0     0.000000  0.000000  0.190476  0.000000  ...  0.125029  0.000287
# 1     0.046512  0.000000  0.093023  0.046512  ... -0.139132 -0.051193
# 2     0.033333  0.066667  0.066667  0.000000  ...  0.061255 -0.004903
# 3     0.047619  0.047619  0.142857  0.047619  ...  0.040203 -0.007535
# 4     0.020833  0.000000  0.125000  0.000000  ... -0.147841 -0.013836
# ...        ...       ...       ...       ...  ...       ...       ...
# 4037  0.093023  0.127907  0.046512  0.023256  ... -0.087141 -0.016207
# 4038  0.023256  0.069767  0.069767  0.011628  ... -0.062792  0.001243
# 4039  0.018868  0.113208  0.056604  0.018868  ... -0.136874 -0.010065
# 4040  0.066667  0.066667  0.000000  0.133333  ... -0.064352 -0.036118
# 4041  0.080000  0.080000  0.000000  0.080000  ...  0.165536 -0.026004
#
#           6158      6159      6160      6161      6162      6163      6164  \
# 0     0.031710  0.045591 -0.068033  0.031241 -0.075914 -0.014122  0.013585
# 1     0.108947 -0.014495 -0.107359  0.016725  0.050440 -0.053858 -0.121933
# 2     0.041961  0.052808 -0.083791  0.009830 -0.080044  0.072112 -0.031148
# 3     0.038144  0.009323 -0.134387  0.005756 -0.134904 -0.035848  0.051515
# 4     0.051293  0.002145 -0.141400  0.038845 -0.136291  0.054276 -0.005753
# ...        ...       ...       ...       ...       ...       ...       ...
# 4037  0.027803 -0.015408 -0.128817 -0.115971 -0.076693  0.077499  0.173814
# 4038  0.043942  0.015509 -0.140289  0.023302 -0.101669  0.015073  0.017768
# 4039  0.022892  0.006662 -0.144792  0.014618 -0.048879 -0.037886  0.024097
# 4040  0.038847 -0.005325 -0.162470 -0.013375  0.012879  0.061577  0.170036
# 4041  0.047379 -0.002521 -0.150257  0.028818 -0.092182  0.051275  0.055207
#
#       label
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 4037    0.0
# 4038    0.0
# 4039    0.0
# 4040    0.0
# 4041    0.0
#
# [4042 rows x 6167 columns]
